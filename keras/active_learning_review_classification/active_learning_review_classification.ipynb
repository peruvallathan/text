# %% [markdown]
# # Review Classification using Active Learning
#
# **Author:** [Darshan Deshpande](https://twitter.com/getdarshan)<br>
# **Date created:** 2021/10/29<br>
# **Last modified:** 2021/10/29<br>
# **Description:** Demonstrating the advantages of active learning through review classification.

# %% [markdown]
# ## Introduction
#
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity
# amongst businesses and researchers. Active Learning seeks to progressively
# train ML models so that the resultant model requires lesser amount of training data to
# achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The
# oracle is an annotator that cleans, selects, labels the data, and feeds it to the model
# when required. The oracle is a trained individual or a group of individuals that
# ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an
# initial model. The best model checkpoint is saved and then tested on a balanced test
# set. The test set must be carefully sampled because the full training process will be
# dependent on it. Once we have the initial evaluation scores, the oracle is tasked with
# labeling more samples; the number of data points to be sampled is usually determined by
# the business requirements. After that, the newly sampled data is added to the training
# set, and the training procedure repeats. This cycle continues until either an
# acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by
# demonstrating a ratio-based (least confidence) sampling strategy that results in lower
# overall false positive and negative rates when compared to a model trained on the entire
# dataset. This sampling falls under the domain of *uncertainty sampling*, in which new
# datasets are sampled based on the uncertainty that the model outputs for the
# corresponding label. In our example, we compare our model's false positive and false
# negative rates and annotate the new data based on their ratio.
#
# Some other sampling techniques include:
#
# 1. [Committee sampling](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Using multiple models to vote for the best data points to be sampled
# 2. [Entropy reduction](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Sampling according to an entropy threshold, selecting more of the samples that produce the highest entropy score.
# 3. [Minimum margin based sampling](https://arxiv.org/abs/1906.00025v1):
# Selects data points closest to the decision boundary

# %% [markdown]
# ## Importing required libraries

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()
# Out:
# 2023-07-06 00:20:28.608680: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ## Loading and preprocessing the data
#
# We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000
# reviews in total, including training and testing splits. We will merge these splits and
# sample our own, balanced training, validation and testing sets.

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# 2023-07-06 00:20:29.627876: W tensorflow/core/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: metadata".
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /home/zlabs-hwa-01/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dataset imdb_reviews downloaded and prepared to /home/zlabs-hwa-01/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# 2023-07-06 00:21:41.779522: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2023-07-06 00:21:41.779560: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: zlabshwa01
# 2023-07-06 00:21:41.779565: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: zlabshwa01
# 2023-07-06 00:21:41.779665: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 530.30.2
# 2023-07-06 00:21:41.779680: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.105.1
# 2023-07-06 00:21:41.779684: E tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 515.105.1 does not match DSO version 530.30.2 -- cannot find working devices in this configuration
# 2023-07-06 00:21:41.780681: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Total examples: 50000

# %% [markdown]
# Active learning starts with labeling a subset of data.
# For the ratio sampling technique that we will be using, we will need well-balanced training,
# validation and testing splits.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# ### Fitting the `TextVectorization` layer
#
# Since we are working with text data, we will need to encode the text strings as vectors which
# would then be passed through an `Embedding` layer. To make this tokenization process
# faster, we use the `map()` function with its parallelization functionality.

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )


vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# ## Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Creating the Model
#
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure
# that the model architecture is capable of overfitting to the initial data.
# Overfitting gives a strong hint that the model will have enough capacity for
# future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# ## Training on the entire dataset
#
# To show the effectiveness of Active Learning, we will first train the model on the entire
# dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.h5", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.h5")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 128)          384000
#
#  bidirectional (Bidirectiona  (None, 150, 64)          41216
#  l)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 20)                1300
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.5325 - binary_accuracy: 0.7476 - false_negatives: 3250.0000 - false_positives: 6831.0000
# Epoch 1: val_loss improved from inf to 0.46632, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 14s 76ms/step - loss: 0.5323 - binary_accuracy: 0.7478 - false_negatives: 3254.0000 - false_positives: 6835.0000 - val_loss: 0.4663 - val_binary_accuracy: 0.7742 - val_false_negatives: 1039.0000 - val_false_positives: 90.0000
# Epoch 2/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.3741 - binary_accuracy: 0.8471 - false_negatives: 3101.0000 - false_positives: 3004.0000
# Epoch 2: val_loss improved from 0.46632 to 0.35661, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 11s 69ms/step - loss: 0.3742 - binary_accuracy: 0.8471 - false_negatives: 3104.0000 - false_positives: 3011.0000 - val_loss: 0.3566 - val_binary_accuracy: 0.8474 - val_false_negatives: 500.0000 - val_false_positives: 263.0000
# Epoch 3/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3367 - binary_accuracy: 0.8692 - false_negatives: 2586.0000 - false_positives: 2647.0000
# Epoch 3: val_loss improved from 0.35661 to 0.32589, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 11s 70ms/step - loss: 0.3367 - binary_accuracy: 0.8692 - false_negatives: 2586.0000 - false_positives: 2647.0000 - val_loss: 0.3259 - val_binary_accuracy: 0.8622 - val_false_negatives: 336.0000 - val_false_positives: 353.0000
# Epoch 4/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3125 - binary_accuracy: 0.8781 - false_negatives: 2350.0000 - false_positives: 2528.0000
# Epoch 4: val_loss did not improve from 0.32589
# 157/157 [==============================] - 11s 71ms/step - loss: 0.3125 - binary_accuracy: 0.8781 - false_negatives: 2350.0000 - false_positives: 2528.0000 - val_loss: 0.3620 - val_binary_accuracy: 0.8410 - val_false_negatives: 602.0000 - val_false_positives: 193.0000
# Epoch 5/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3003 - binary_accuracy: 0.8859 - false_negatives: 2165.0000 - false_positives: 2399.0000
# Epoch 5: val_loss did not improve from 0.32589
# 157/157 [==============================] - 11s 69ms/step - loss: 0.3003 - binary_accuracy: 0.8859 - false_negatives: 2165.0000 - false_positives: 2399.0000 - val_loss: 0.3651 - val_binary_accuracy: 0.8372 - val_false_negatives: 658.0000 - val_false_positives: 156.0000
# Epoch 6/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2824 - binary_accuracy: 0.8917 - false_negatives: 2080.0000 - false_positives: 2251.0000
# Epoch 6: val_loss did not improve from 0.32589
# 157/157 [==============================] - 11s 70ms/step - loss: 0.2824 - binary_accuracy: 0.8917 - false_negatives: 2080.0000 - false_positives: 2251.0000 - val_loss: 0.3484 - val_binary_accuracy: 0.8558 - val_false_negatives: 469.0000 - val_false_positives: 252.0000
# Epoch 7/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2711 - binary_accuracy: 0.8999 - false_negatives: 1878.0000 - false_positives: 2120.0000
# Epoch 7: val_loss did not improve from 0.32589
# 157/157 [==============================] - 11s 70ms/step - loss: 0.2712 - binary_accuracy: 0.8998 - false_negatives: 1883.0000 - false_positives: 2125.0000 - val_loss: 0.3400 - val_binary_accuracy: 0.8562 - val_false_negatives: 453.0000 - val_false_positives: 266.0000
# Epoch 7: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3284223973751068, 'binary_accuracy': 0.86080002784729, 'false_negatives': 357.0, 'false_positives': 339.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
#
# ![Active Learning](https://i.imgur.com/dmNKusp.png)
#
# The pipeline can be summarized in five parts:
#
# 1. Sample and annotate a small, balanced training dataset
# 2. Train the model on this small subset
# 3. Evaluate the model on a balanced testing set
# 4. If the model satisfies the business criteria, deploy it in a real time setting
# 5. If it doesn't pass the criteria, sample a few more samples according to the ratio of
# false positives and negatives, add them to the training set and repeat from step 2 till
# the model passes the tests or till all available data is exhausted.
#
# For the code below, we will perform sampling using the following formula:<br/>
#
# ![Ratio Sampling](https://i.imgur.com/LyZEiZL.png)
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be
# using model checkpointing and early stopping for this example. The `patience` parameter
# for Early Stopping can help minimize overfitting and the time required. We have set it
# `patience=4` for now but since the model is robust, we can increase the patience level if
# desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my
# experience working on Active Learning techniques, this helps the model probe the
# newly formed loss landscape. Even if the model fails to improve in the second iteration,
# we will still gain insight about the possible future false positive and negative rates.
# This will help us sample a better set in the next iteration where the model will have a
# greater chance to improve.

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 150, 128)          384000
#
#  bidirectional_1 (Bidirectio  (None, 150, 64)          41216
#  nal)
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 20)                1300
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 15000 samples
# Epoch 1/20
# 59/59 [==============================] - ETA: 0s - loss: 0.6285 - binary_accuracy: 0.6559 - false_negatives_1: 3402.0000 - false_positives_1: 1760.0000
# Epoch 1: val_loss improved from inf to 0.45699, saving model to AL_Model.h5
# 59/59 [==============================] - 7s 82ms/step - loss: 0.6285 - binary_accuracy: 0.6559 - false_negatives_1: 3402.0000 - false_positives_1: 1760.0000 - val_loss: 0.4570 - val_binary_accuracy: 0.8028 - val_false_negatives_1: 389.0000 - val_false_positives_1: 597.0000
# Epoch 2/20
# 59/59 [==============================] - ETA: 0s - loss: 0.4541 - binary_accuracy: 0.8094 - false_negatives_1: 1338.0000 - false_positives_1: 1521.0000
# Epoch 2: val_loss improved from 0.45699 to 0.37682, saving model to AL_Model.h5
# 59/59 [==============================] - 4s 75ms/step - loss: 0.4541 - binary_accuracy: 0.8094 - false_negatives_1: 1338.0000 - false_positives_1: 1521.0000 - val_loss: 0.3768 - val_binary_accuracy: 0.8448 - val_false_negatives_1: 352.0000 - val_false_positives_1: 424.0000
# Epoch 3/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.3937 - binary_accuracy: 0.8404 - false_negatives_1: 1116.0000 - false_positives_1: 1253.0000
# Epoch 3: val_loss improved from 0.37682 to 0.36933, saving model to AL_Model.h5
# 59/59 [==============================] - 4s 75ms/step - loss: 0.3927 - binary_accuracy: 0.8408 - false_negatives_1: 1120.0000 - false_positives_1: 1268.0000 - val_loss: 0.3693 - val_binary_accuracy: 0.8394 - val_false_negatives_1: 516.0000 - val_false_positives_1: 287.0000
# Epoch 4/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.3619 - binary_accuracy: 0.8563 - false_negatives_1: 1002.0000 - false_positives_1: 1132.0000
# Epoch 4: val_loss improved from 0.36933 to 0.35708, saving model to AL_Model.h5
# 59/59 [==============================] - 4s 74ms/step - loss: 0.3625 - binary_accuracy: 0.8555 - false_negatives_1: 1029.0000 - false_positives_1: 1139.0000 - val_loss: 0.3571 - val_binary_accuracy: 0.8470 - val_false_negatives_1: 261.0000 - val_false_positives_1: 504.0000
# Epoch 5/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3227 - binary_accuracy: 0.8777 - false_negatives_1: 855.0000 - false_positives_1: 980.0000
# Epoch 5: val_loss did not improve from 0.35708
# 59/59 [==============================] - 4s 75ms/step - loss: 0.3227 - binary_accuracy: 0.8777 - false_negatives_1: 855.0000 - false_positives_1: 980.0000 - val_loss: 0.3610 - val_binary_accuracy: 0.8422 - val_false_negatives_1: 254.0000 - val_false_positives_1: 535.0000
# Epoch 6/20
# 59/59 [==============================] - ETA: 0s - loss: 0.2973 - binary_accuracy: 0.8872 - false_negatives_1: 769.0000 - false_positives_1: 923.0000
# Epoch 6: val_loss did not improve from 0.35708
# 59/59 [==============================] - 4s 76ms/step - loss: 0.2973 - binary_accuracy: 0.8872 - false_negatives_1: 769.0000 - false_positives_1: 923.0000 - val_loss: 0.3826 - val_binary_accuracy: 0.8382 - val_false_negatives_1: 537.0000 - val_false_positives_1: 272.0000
# Epoch 7/20
# 59/59 [==============================] - ETA: 0s - loss: 0.2806 - binary_accuracy: 0.8979 - false_negatives_1: 719.0000 - false_positives_1: 813.0000
# Epoch 7: val_loss did not improve from 0.35708
# 59/59 [==============================] - 4s 75ms/step - loss: 0.2806 - binary_accuracy: 0.8979 - false_negatives_1: 719.0000 - false_positives_1: 813.0000 - val_loss: 0.4166 - val_binary_accuracy: 0.8254 - val_false_negatives_1: 182.0000 - val_false_positives_1: 691.0000
# Epoch 8/20
# 59/59 [==============================] - ETA: 0s - loss: 0.2633 - binary_accuracy: 0.9007 - false_negatives_1: 692.0000 - false_positives_1: 797.0000
# Epoch 8: val_loss did not improve from 0.35708
# 59/59 [==============================] - 5s 76ms/step - loss: 0.2633 - binary_accuracy: 0.9007 - false_negatives_1: 692.0000 - false_positives_1: 797.0000 - val_loss: 0.3806 - val_binary_accuracy: 0.8382 - val_false_negatives_1: 495.0000 - val_false_positives_1: 314.0000
# Epoch 8: early stopping
# 20/20 [==============================] - 1s 23ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 523.0, Number of ones incorrectly classified: 300.0
# Sample ratio for positives: 0.3645200486026732, Sample ratio for negatives:0.6354799513973268
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 79/79 [==============================] - ETA: 0s - loss: 0.3022 - binary_accuracy: 0.8850 - false_negatives_2: 1070.0000 - false_positives_2: 1230.0000
# Epoch 1: val_loss did not improve from 0.35708
# 79/79 [==============================] - 9s 80ms/step - loss: 0.3022 - binary_accuracy: 0.8850 - false_negatives_2: 1070.0000 - false_positives_2: 1230.0000 - val_loss: 0.3618 - val_binary_accuracy: 0.8496 - val_false_negatives_2: 348.0000 - val_false_positives_2: 404.0000
# Epoch 2/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.2726 - binary_accuracy: 0.9001 - false_negatives_2: 943.0000 - false_positives_2: 1051.0000
# Epoch 2: val_loss did not improve from 0.35708
# 79/79 [==============================] - 6s 74ms/step - loss: 0.2724 - binary_accuracy: 0.9002 - false_negatives_2: 944.0000 - false_positives_2: 1051.0000 - val_loss: 0.3736 - val_binary_accuracy: 0.8434 - val_false_negatives_2: 271.0000 - val_false_positives_2: 512.0000
# Epoch 3/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.2487 - binary_accuracy: 0.9101 - false_negatives_2: 846.0000 - false_positives_2: 950.0000
# Epoch 3: val_loss did not improve from 0.35708
# 79/79 [==============================] - 6s 74ms/step - loss: 0.2489 - binary_accuracy: 0.9100 - false_negatives_2: 849.0000 - false_positives_2: 951.0000 - val_loss: 0.4209 - val_binary_accuracy: 0.8294 - val_false_negatives_2: 207.0000 - val_false_positives_2: 646.0000
# Epoch 4/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2312 - binary_accuracy: 0.9180 - false_negatives_2: 785.0000 - false_positives_2: 855.0000
# Epoch 4: val_loss did not improve from 0.35708
# 79/79 [==============================] - 6s 74ms/step - loss: 0.2312 - binary_accuracy: 0.9180 - false_negatives_2: 785.0000 - false_positives_2: 855.0000 - val_loss: 0.4121 - val_binary_accuracy: 0.8372 - val_false_negatives_2: 529.0000 - val_false_positives_2: 285.0000
# Epoch 5/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.2190 - binary_accuracy: 0.9207 - false_negatives_2: 731.0000 - false_positives_2: 852.0000
# Epoch 5: val_loss did not improve from 0.35708
# 79/79 [==============================] - 6s 75ms/step - loss: 0.2190 - binary_accuracy: 0.9207 - false_negatives_2: 732.0000 - false_positives_2: 853.0000 - val_loss: 0.4258 - val_binary_accuracy: 0.8388 - val_false_negatives_2: 328.0000 - val_false_positives_2: 478.0000
# Epoch 5: early stopping
# 20/20 [==============================] - 1s 24ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 287.0, Number of ones incorrectly classified: 499.0
# Sample ratio for positives: 0.6348600508905853, Sample ratio for negatives:0.3651399491094148
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3575 - binary_accuracy: 0.8565 - false_negatives_3: 1752.0000 - false_positives_3: 1836.0000
# Epoch 1: val_loss did not improve from 0.35708
# 98/98 [==============================] - 10s 80ms/step - loss: 0.3575 - binary_accuracy: 0.8565 - false_negatives_3: 1752.0000 - false_positives_3: 1836.0000 - val_loss: 0.3966 - val_binary_accuracy: 0.8246 - val_false_negatives_3: 698.0000 - val_false_positives_3: 179.0000
# Epoch 2/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3236 - binary_accuracy: 0.8720 - false_negatives_3: 1542.0000 - false_positives_3: 1658.0000
# Epoch 2: val_loss did not improve from 0.35708
# 98/98 [==============================] - 7s 74ms/step - loss: 0.3236 - binary_accuracy: 0.8720 - false_negatives_3: 1542.0000 - false_positives_3: 1658.0000 - val_loss: 0.3603 - val_binary_accuracy: 0.8474 - val_false_negatives_3: 530.0000 - val_false_positives_3: 233.0000
# Epoch 3/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3003 - binary_accuracy: 0.8859 - false_negatives_3: 1339.0000 - false_positives_3: 1514.0000
# Epoch 3: val_loss did not improve from 0.35708
# 98/98 [==============================] - 7s 74ms/step - loss: 0.3003 - binary_accuracy: 0.8859 - false_negatives_3: 1339.0000 - false_positives_3: 1514.0000 - val_loss: 0.3869 - val_binary_accuracy: 0.8404 - val_false_negatives_3: 238.0000 - val_false_positives_3: 560.0000
# Epoch 4/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2787 - binary_accuracy: 0.8961 - false_negatives_3: 1248.0000 - false_positives_3: 1350.0000
# Epoch 4: val_loss improved from 0.35708 to 0.34021, saving model to AL_Model.h5
# 98/98 [==============================] - 7s 75ms/step - loss: 0.2787 - binary_accuracy: 0.8961 - false_negatives_3: 1248.0000 - false_positives_3: 1350.0000 - val_loss: 0.3402 - val_binary_accuracy: 0.8524 - val_false_negatives_3: 335.0000 - val_false_positives_3: 403.0000
# Epoch 5/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.2642 - binary_accuracy: 0.8979 - false_negatives_3: 1210.0000 - false_positives_3: 1325.0000
# Epoch 5: val_loss did not improve from 0.34021
# 98/98 [==============================] - 7s 73ms/step - loss: 0.2638 - binary_accuracy: 0.8982 - false_negatives_3: 1212.0000 - false_positives_3: 1333.0000 - val_loss: 0.3929 - val_binary_accuracy: 0.8398 - val_false_negatives_3: 536.0000 - val_false_positives_3: 265.0000
# Epoch 6/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2508 - binary_accuracy: 0.9067 - false_negatives_3: 1121.0000 - false_positives_3: 1212.0000
# Epoch 6: val_loss did not improve from 0.34021
# 98/98 [==============================] - 7s 74ms/step - loss: 0.2508 - binary_accuracy: 0.9067 - false_negatives_3: 1121.0000 - false_positives_3: 1212.0000 - val_loss: 0.3510 - val_binary_accuracy: 0.8432 - val_false_negatives_3: 363.0000 - val_false_positives_3: 421.0000
# Epoch 7/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2350 - binary_accuracy: 0.9149 - false_negatives_3: 991.0000 - false_positives_3: 1137.0000
# Epoch 7: val_loss did not improve from 0.34021
# 98/98 [==============================] - 7s 74ms/step - loss: 0.2350 - binary_accuracy: 0.9149 - false_negatives_3: 991.0000 - false_positives_3: 1137.0000 - val_loss: 0.3790 - val_binary_accuracy: 0.8430 - val_false_negatives_3: 303.0000 - val_false_positives_3: 482.0000
# Epoch 8/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2218 - binary_accuracy: 0.9220 - false_negatives_3: 916.0000 - false_positives_3: 1034.0000
# Epoch 8: val_loss did not improve from 0.34021
# 98/98 [==============================] - 7s 75ms/step - loss: 0.2218 - binary_accuracy: 0.9220 - false_negatives_3: 916.0000 - false_positives_3: 1034.0000 - val_loss: 0.3992 - val_binary_accuracy: 0.8306 - val_false_negatives_3: 560.0000 - val_false_positives_3: 287.0000
# Epoch 8: early stopping
# 20/20 [==============================] - 1s 23ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 351.0, Number of ones incorrectly classified: 382.0
# Sample ratio for positives: 0.5211459754433834, Sample ratio for negatives:0.47885402455661663
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2972 - binary_accuracy: 0.8888 - false_negatives_4: 1516.0000 - false_positives_4: 1820.0000
# Epoch 1: val_loss did not improve from 0.34021
# 118/118 [==============================] - 12s 84ms/step - loss: 0.2972 - binary_accuracy: 0.8888 - false_negatives_4: 1516.0000 - false_positives_4: 1820.0000 - val_loss: 0.3549 - val_binary_accuracy: 0.8482 - val_false_negatives_4: 263.0000 - val_false_positives_4: 496.0000
# Epoch 2/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2682 - binary_accuracy: 0.8973 - false_negatives_4: 1436.0000 - false_positives_4: 1641.0000
# Epoch 2: val_loss did not improve from 0.34021
# 118/118 [==============================] - 9s 74ms/step - loss: 0.2681 - binary_accuracy: 0.8974 - false_negatives_4: 1437.0000 - false_positives_4: 1642.0000 - val_loss: 0.3512 - val_binary_accuracy: 0.8486 - val_false_negatives_4: 273.0000 - val_false_positives_4: 484.0000
# Epoch 3/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2542 - binary_accuracy: 0.9043 - false_negatives_4: 1338.0000 - false_positives_4: 1529.0000
# Epoch 3: val_loss did not improve from 0.34021
# 118/118 [==============================] - 9s 72ms/step - loss: 0.2541 - binary_accuracy: 0.9044 - false_negatives_4: 1338.0000 - false_positives_4: 1531.0000 - val_loss: 0.4200 - val_binary_accuracy: 0.8334 - val_false_negatives_4: 598.0000 - val_false_positives_4: 235.0000
# Epoch 4/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2384 - binary_accuracy: 0.9128 - false_negatives_4: 1187.0000 - false_positives_4: 1428.0000
# Epoch 4: val_loss did not improve from 0.34021
# 118/118 [==============================] - 9s 73ms/step - loss: 0.2384 - binary_accuracy: 0.9128 - false_negatives_4: 1187.0000 - false_positives_4: 1428.0000 - val_loss: 0.3991 - val_binary_accuracy: 0.8444 - val_false_negatives_4: 257.0000 - val_false_positives_4: 521.0000
# Epoch 5/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2235 - binary_accuracy: 0.9186 - false_negatives_4: 1157.0000 - false_positives_4: 1281.0000
# Epoch 5: val_loss did not improve from 0.34021
# 118/118 [==============================] - 9s 73ms/step - loss: 0.2236 - binary_accuracy: 0.9186 - false_negatives_4: 1157.0000 - false_positives_4: 1284.0000 - val_loss: 0.4611 - val_binary_accuracy: 0.8182 - val_false_negatives_4: 732.0000 - val_false_positives_4: 177.0000
# Epoch 6/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2035 - binary_accuracy: 0.9251 - false_negatives_4: 1076.0000 - false_positives_4: 1166.0000
# Epoch 6: val_loss did not improve from 0.34021
# 118/118 [==============================] - 9s 73ms/step - loss: 0.2034 - binary_accuracy: 0.9252 - false_negatives_4: 1076.0000 - false_positives_4: 1168.0000 - val_loss: 0.4285 - val_binary_accuracy: 0.8454 - val_false_negatives_4: 383.0000 - val_false_positives_4: 390.0000
# Epoch 6: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3437609374523163, 'binary_accuracy': 0.8533999919891357, 'false_negatives_3': 351.0, 'false_positives_3': 382.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusion
#
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency
# benefits of using Active Learning, as it eliminates the need to annotate large amounts of
# data, saving resources.
#
# The following are some noteworthy observations from this example:
#
# 1. We only require 30,000 samples to reach the same (if not better) scores as the model
# trained on the full datatset. This means that in a real life setting, we save the effort
# required for annotating 10,000 images!
# 2. The number of false negatives and false positives are well balanced at the end of the
# training as compared to the skewed ratio obtained from the full training. This makes the
# model slightly more useful in real life scenarios where both the labels hold equal
# importance.
#
# For further reading about the types of sampling ratios, training techniques or available
# open source libraries/implementations, you can refer to the resources below:
#
# 1. [Active Learning Literature Survey](http://burrsettles.com/pub/settles.activelearning.pdf) (Burr Settles, 2010).
# 2. [modAL](https://github.com/modAL-python/modAL): A Modular Active Learning framework.
# 3. Google's unofficial [Active Learning playground](https://github.com/google/active-learning).
